# %%
import pandas as pd

# %%
dataset=pd.read_csv("Placement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
#First we check null or nan values are there
dataset.isnull().sum()
#dataset.isna().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %% [markdown]
# # What are the different methods to preprocess the data using Data Preprocessing

# %% [markdown]
# 1)Replacing the missing value with central Tendency -Mean ,Median,Mode.(Mostly Categorical Data Handled by Mode)
# 2)Entire Row delete.
# 3)Respective to the problem statement ,have to replace the missing values.
# 4)Consider this as a semi-supervised,create a model, so that we can predict the missing values .

# %% [markdown]
# In our assignment we use 3rd method Respective to the problem statement,have to replace the missing values

# %% [markdown]
# ## 1)Replace the NaN values with correct values .And Justify why you have chosen the same

# %% [markdown]
# #In this dataset salary have 67 nan values
# #Using fillna we replace the value because not placed student cannot get salary .
# #So we use this method .
# #The nan values are filled with zero

# %%
#we cannot assign variable so we use inplace =True you can store that in dataset
dataset["salary"].fillna(0,inplace=True)

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# ## 2)How many of them are not placed ?

# %%
print(dataset['status'].value_counts()['Not Placed'])
# Out:
# 67

# %% [markdown]
# # 67 Students are Not placed

# %% [markdown]
# ### 3)Find the reason for non placement from the dataset

# %%
df= dataset[dataset['status'] == 'Not Placed']
df
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 3        4      M   56.0  Central   52.0  Central   Science     52.00
# 5        6      M   55.0   Others   49.8   Others   Science     67.25
# 6        7      F   46.0   Others   49.2   Others  Commerce     79.00
# 9       10      M   58.0  Central   70.0  Central  Commerce     61.00
# 12      13      F   47.0  Central   55.0   Others   Science     65.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 198    199      F   67.0  Central   70.0  Central  Commerce     65.00
# 201    202      M   54.2  Central   63.0   Others   Science     58.00
# 206    207      M   41.0  Central   42.0  Central   Science     60.00
# 208    209      F   43.0  Central   60.0   Others   Science     65.00
# 214    215      M   62.0  Central   58.0   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status  salary
# ...

# %%
df["ssc_b"].dtypes
# Out:
# dtype('O')

# %%
def quanQual(df):
    quan=[]
    qual=[]
    for columnName in df.columns:
    #print(columnName)
        if(df[columnName].dtypes=='O'):
        #print("qual")
            qual.append(columnName)
        else:
        #print("quan")
             quan.append(columnName)
    return quan,qual

# %%
quan,qual=quanQual(df)

# %%
quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
descriptive=pd.DataFrame(index=["Median"],columns=quan)
for columnName in quan:
    descriptive[columnName]["Median"]=df[columnName].median()

# %%
descriptive
# Out:
#        sl_no  ssc_p  hsc_p degree_p etest_p  mba_p salary
# Median   107  56.28  60.33       61      67  60.69      0

# %%
df1= dataset[dataset['status'] == 'Placed']
df1
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 7        8      M  82.00  Central  64.00  Central   Science     66.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 209    210      M  62.00  Central  72.00  Central  Commerce     65.00
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# ...

# %%
def quanQual1(df1):
    quan1=[]
    qual1=[]
    for colunName in df1.columns:
    #print(columnName)
        if(df1[colunName].dtypes=='O'):
        #print("qual")
            qual1.append(colunName)
        else:
        #print("quan")
             quan1.append(colunName)
    return quan1,qual1

# %%
quan1,qual1=quanQual1(df1)

# %%
quan1
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
descriptive1=pd.DataFrame(index=["Median"],columns=quan1)
for colunName in quan1:
    descriptive1[colunName]["Median"]=df1[colunName].median()

# %%
descriptive1
# Out:
#         sl_no ssc_p hsc_p degree_p etest_p   mba_p  salary
# Median  108.5  72.5    68       68      72  62.245  265000

# %% [markdown]
# # Find the reason for non placement -justify

# %% [markdown]
# comparing the Not placed student median and Placed student median

# %% [markdown]
# In Not placed student ,Upto ssc_p to etest_p the average is less than 68% .So below 68% pass mark students are not placed .
# In Placed Student,Upto ssc_p to etest_p the average is greater than or equal to 68%.So above 68% passmark students are placed

# %% [markdown]
# # 4) What kind of relation between salary and mba_p

# %%
#correlation
dataset.corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.002543
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.002543  0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %% [markdown]
# # What kind of relation between salary and mba_p-Justify

# %% [markdown]
# Correlation-Relationship between 2 columns.
# salary,mba_p.
# Positive correlation,13% directly proportional.

# %% [markdown]
# # 5)Which specialization is getting minimum salary?

# %%
df1.sort_values(by="salary",ascending =True)
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 107    108      M  82.00   Others  90.00   Others  Commerce     83.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 135    136      F  72.00  Central  56.00   Others   Science     69.00
# 50      51      F  75.20  Central  73.20  Central   Science     68.40
# 44      45      F  77.00   Others  73.00   Others  Commerce     81.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 163    164      M  63.00   Others  67.00   Others   Science     64.00
# 77      78      M  64.00   Others  80.00   Others   Science     65.00
# 177    178      F  73.00  Central  97.00   Others  Commerce     79.00
# 150    151      M  71.00  Central  58.66  Central   Science     58.00
# 119    120      M  60.80  Central  68.40  Central  Commerce     64.60
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# ...

# %% [markdown]
# # Which specialisation is getting minimum salary

# %% [markdown]
# Mkt&HR and Mkt&Fin Specialisation getting minimum salary .The minimum salary is 200000

# %% [markdown]
# # 6)How many of them getting above 500000 salary ?

# %%
val=dataset[dataset['salary'] > 500000]
val
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 119    120      M   60.8  Central  68.40  Central  Commerce      64.6
# 150    151      M   71.0  Central  58.66  Central   Science      58.0
# 177    178      F   73.0  Central  97.00   Others  Commerce      79.0
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# 119  Comm&Mgmt    Yes    82.66        Mkt&Fin  64.34  Placed  940000.0
# 150   Sci&Tech    Yes    56.00        Mkt&Fin  61.30  Placed  690000.0
# 177  Comm&Mgmt    Yes    89.00        Mkt&Fin  70.81  Placed  650000.0

# %%
val.count()
# Out:
# sl_no             3
# gender            3
# ssc_p             3
# ssc_b             3
# hsc_p             3
# hsc_b             3
# hsc_s             3
# degree_p          3
# degree_t          3
# workex            3
# etest_p           3
# specialisation    3
# mba_p             3
# status            3
# salary            3
# dtype: int64

# %% [markdown]
# # How many of them getting above 500000 salary?

# %% [markdown]
# 3 of them getting above 500000 salary .

# %% [markdown]
# # 7)Test the Analysis of variance between etest_p and mba_p at significance level 5% (Make decision using Hypothesis testing )

# %%
import scipy.stats as stats
stats.f_oneway(dataset["etest_p"],dataset["mba_p"])
# Out:
# F_onewayResult(statistic=98.64487057324706, pvalue=4.672547689133573e-21)

# %% [markdown]
# H0-There is no significant between this columns.
# H1-There is significant between this columns.
# Accept H0 ,Reject H1.

# %% [markdown]
# # Analysis of Variance-Justify

# %% [markdown]
# P value is greater than 5% . so Accept H0 and Reject H1

# %% [markdown]
# # 8)Test the similarity between the degree_t(Sci&Tech) and specialization(Mkt&HR) with respect to salary at significant level of 5%(Make decision using Hypothesis testing)

# %% [markdown]
# Independent Sample-Unpaired T Test.
# Different group(degree_t,specialisation)but same condition(salary)

# %%
from scipy.stats import ttest_ind
#drop null values
dataset=dataset.dropna()
degree=dataset[dataset["degree_t"]=="Sci&Tech"]["salary"]
spec=dataset[dataset["specialisation"]=="Mkt&HR"]["salary"]

ttest_ind(degree,spec)
# Out:
# Ttest_indResult(statistic=2.692041243555374, pvalue=0.007897969943471179)

# %% [markdown]
# Hypothesis testing.
# Statement:Test the similarity between the degree_t(Sci&Tech)and specialisation(Mkt&HR) with respect to salary.
# Alternative hypothesis -there is  similarity between degree_t of sci&Tech and specialisation of mkt&hr

# %% [markdown]
# solution:
# P value is less than 5%.so it accept Alternative Hypothesis and reject Null hypothesis.

# %% [markdown]
# # 9)Convert the normal distribution to standardnormal distribution for salary columns

# %%
#Standard Normalisation
def stdNBgraph(dataset):
    import seaborn as sns
    #mean and std calculation
    mean=dataset.mean()
    std=dataset.std()
    #Oneliner advantage of oneliner is in single line the output is converted into list 
    values=[i for i in dataset]
    #formula calculation
    z_score=[((j-mean)/std) for j in values]
    #kde(Kernel density function )=True the curve is dislayed
    sns.distplot(z_score,kde=True)
    sum(z_score)/len(z_score)

# %%
stdNBgraph(dataset["salary"])
# Out:
# C:\Users\spavi\Anaconda3\Anaconda\envs\aiml\lib\site-packages\ipykernel_launcher.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   if sys.path[0] == "":

# %% [markdown]
# # 10)What is the probability Density Function of the salary range from 700000 to 900000 ?

# %%
#what is the probability of getting mark 60 to 70
def get_pdf_probability(dataset,startrange,endrange):
    from matplotlib import pyplot
    # inbuilt function for normal distribution so we import this library
    from scipy.stats import norm
    import seaborn as sns
    #In distplot kde(Kernel density function)=True the curve will display
    ax=sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color="Green")
    #axvline is vertical line startrange and the color is red
    pyplot.axvline(startrange,color='Red')
    #axvline is vertical line startrange and the color is red
    pyplot.axvline(endrange,color="Red")
    #Until this line the graph is created
    #Below lines for calculation
    #generate a sample
    sample=dataset
    #calculate parameters
    sample_mean=sample.mean()
    sample_std=sample.std()
    print('Mean=%.3f , Standard Deviation=%.3f' % (sample_mean, sample_std))
    #define the distribution
    #inbuilt normal distribution function
    dist=norm(sample_mean,sample_std)
    
    #sample probabilities for a range of outcomes
    #advantage of below line is in single line the output is converted into list it is called oneliner for loop
    values=[value for value in range(startrange,endrange)]
    probabilities=[dist.pdf(value)for value in values]
    prob=sum(probabilities)
    print("The area between range ({},{}):{}".format(startrange,endrange,sum(probabilities)))
    return prob

# %%
get_pdf_probability(dataset["salary"],700000,900000)
# Out:
# C:\Users\spavi\Anaconda3\Anaconda\envs\aiml\lib\site-packages\ipykernel_launcher.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# Mean=198702.326 , Standard Deviation=154780.927
# The area between range (700000,900000):0.0005973310593974868
# 0.0005973310593974868

# %% [markdown]
# # 11)Test the similarity between the degree_t(sci&Tech) with respect to etest_p and mba_p at significance level of 5%(Make decision using Hypothesis Testing)

# %% [markdown]
# Dependent sample-Paired T Test.
# Same group(degree_t)but Different condition(etest_p,mba_p)

# %%
from scipy.stats import ttest_ind
#drop null values
dataset=dataset.dropna()
degree=dataset[dataset["degree_t"]=="Sci&Tech"]["etest_p"]
degree1=dataset[dataset["degree_t"]=="Sci&Tech"]["mba_p"]
#print(male)
ttest_ind(degree,degree1)
# Out:
# Ttest_indResult(statistic=4.532000225151251, pvalue=1.4289217003775636e-05)

# %% [markdown]
# Hypothesis testing.
# Statement:Test whether etest_p of degree_t and mba_p of degree_t at significance level 0f 5%?
# Null hypothesis there is no similarity between etest_p of degree_t and mba_p mark of degree_t.

# %% [markdown]
# solution :
# Accept Null Hypothesis,Reject alternate hypothesis.
# There is no similarity between etest_p of degree_t and mba_p mark of degree_t.

# %% [markdown]
# # 12)Which parameter  is highly correlated with salary ?

# %%
dataset.corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.002543
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.002543  0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %% [markdown]
# ssc_p is highly correlated with salary.

# %% [markdown]
# # 13)Plot any useful graph and explain it

# %%
import seaborn as sns

# %%
#pairplot is for 2 columns
sns.pairplot(dataset)
